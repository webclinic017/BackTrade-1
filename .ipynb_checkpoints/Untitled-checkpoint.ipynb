# %%
import numpy as np
import random
import pandas as pd
import seaborn as sns
import glob

# %%
df = pd.read_csv('./dates/2021-12-09.csv')
print("size of data frame: ", df.shape)
cols = df.columns
for col in cols:
    print(df[f"{col}"].describe())
# Out:
# size of data frame:  (497, 155)
# count    497.000000
# mean     248.000000
# std      143.615807
# min        0.000000
# 25%      124.000000
# 50%      248.000000
# 75%      372.000000
# max      496.000000
# Name: Unnamed: 0, dtype: float64
# count    497.000000
# mean     248.000000
# std      143.615807
# min        0.000000
# 25%      124.000000
# 50%      248.000000
# 75%      372.000000
# max      496.000000
# Name: Unnamed: 0.1, dtype: float64
# count    497.000000
# mean     248.000000
# std      143.615807
# min        0.000000
# 25%      124.000000
# 50%      248.000000
# 75%      372.000000
# max      496.000000
# Name: Unnamed: 0.1.1, dtype: float64
# count      497
# unique     497
# top       AAPL
# freq         1
# Name: ticker, dtype: object
# count     497.000000
# mean      208.546569
# std       381.937352
# min        11.453131
# 25%        62.866439
# 50%       120.220001
# 75%       229.103519
# max      5890.209961
# Name: Open, dtype: float64
# ...

# %%
path = "c:/users/roeym/desktop/backtrade/dates/*.csv"
# df = pd.read_csv("2020-01-24.csv")
dates =[]
for fname in glob.glob(path):
    dates.append(fname.split('/')[5].split(".")[0][6:])
for date in dates:
    df = pd.read_csv(f"{date}.csv")
    df=df.drop(df.columns[[0,1,2,3,4]], axis=1)
    df.to_csv(f"{date}.csv")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\roeym\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\roeym\AppData\Local\Temp/ipykernel_16564/2376040414.py", line 9, in <module>
#     df.to_csv(f"{date}.csv")
#   File "C:\Users\roeym\anaconda3\lib\site-packages\pandas\core\generic.py", line 3466, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "C:\Users\roeym\anaconda3\lib\site-packages\pandas\io\formats\format.py", line 1105, in to_csv
#     csv_formatter.save()
#   File "C:\Users\roeym\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 257, in save
#     self._save()
#   File "C:\Users\roeym\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 262, in _save
#     self._save_body()
# ...
